# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data= ps.read_csv("car data.csv")
df=ps.DataFrame(data)

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df["CarAge"]=2023-df["Year"]

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  CarAge
# 0        Dealer       Manual      0       9
# 1        Dealer       Manual      0      10
# 2        Dealer       Manual      0       6
# 3        Dealer       Manual      0      12
# 4        Dealer       Manual      0       9
# ..          ...          ...    ...     ...
# 296      Dealer       Manual      0       7
# 297      Dealer       Manual      0       8
# 298      Dealer       Manual      0      14
# 299      Dealer       Manual      0       6
# 300      Dealer       Manual      0       7
#
# [301 rows x 10 columns]

# %%
x=df[["CarAge","Kms_Driven","Fuel_Type","Seller_Type","Transmission"]]
x=ps.get_dummies(x)
y=df["Selling_Price"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
z=model.fit(x_train,y_train)
pre=model.predict(x_test)
pre
# Out:
# array([ 5.96066908,  5.32699541,  9.15259618, -0.28858822,  4.35880567,
#        10.0697628 ,  0.86928662,  0.67054657,  1.2024395 ,  9.77857809,
#        11.08846936,  0.27914813,  9.55324246,  6.34176254,  9.49919034,
#         4.2488963 ,  0.09608958,  5.61659853,  1.50602155,  1.53828063,
#         0.37323711, 10.4519002 ,  9.27660546,  3.88964322,  0.5943793 ,
#         4.10182455,  4.28398253,  3.78659338,  1.49526853,  1.18451779,
#         0.3553154 ,  9.69793039, -0.53213255,  2.88122372, 10.34631444,
#         4.66060004,  4.21543646,  3.14268976,  4.28318501,  3.47584264,
#         1.96689321,  6.22102366,  4.73228689,  0.51821202, 10.10980887,
#         0.28362856,  4.63763337,  8.14446366,  4.40361443,  9.18784818,
#         9.1788786 ,  1.52618348, 14.85203884, 15.55418802,  9.98457195,
#        10.04143777,  5.07667668, 10.38669205,  2.35624857, 10.1117536 ,
#         0.29258941])

# %%
from sklearn.metrics import r2_score,mean_squared_error
acc=r2_score(y_test,pre)
mse=mean_squared_error(y_test,pre)

# %%
acc
# Out:
# 0.591149566336626

# %%
mse
# Out:
# 9.418108720809972

# %%
model.intercept_
# Out:
# np.float64(8.983338776811973)

# %%
model.coef_
# Out:
# array([-2.79387747e-01, -4.48042783e-06, -2.55192308e+00,  3.85735270e+00,
#        -1.30542962e+00,  2.05551251e+00, -2.05551251e+00,  2.40151693e+00,
#        -2.40151693e+00])

# %%
print(df.iloc[5])
# Out:
# Car_Name         vitara brezza
# Year                      2018
# Selling_Price             9.25
# Present_Price             9.83
# Kms_Driven                2071
# Fuel_Type               Diesel
# Seller_Type             Dealer
# Transmission            Manual
# Owner                        0
# CarAge                       5
# Name: 5, dtype: object

# %%
x_train
# Out:
#      CarAge  Kms_Driven  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 184      15       26000          False             False              True
# 132       6        3500          False             False              True
# 194      15       50000          False             False              True
# 75        8       36000          False             False              True
# 111       7        8700          False             False              True
# ..      ...         ...            ...               ...               ...
# 188      10       18000          False             False              True
# 71       12       45000          False              True             False
# 106       9       16500          False             False              True
# 270      12       69341          False             False              True
# 102       6        4000          False             False              True
#
#      Seller_Type_Dealer  Seller_Type_Individual  Transmission_Automatic  \
# 184               False                    True                   False
# 132               False                    True                   False
# 194               False                    True                   False
# 75                 True                   False                   False
# 111               False                    True                   False
# ..                  ...                     ...                     ...
# 188               False                    True                   False
# 71                 True                   False                   False
# 106               False                    True                   False
# 270                True                   False                   False
# 102               False                    True                   False
#
#      Transmission_Manual
# 184                 True
# 132                 True
# 194                 True
# 75                  True
# 111                 True
# ..                   ...
# 188                 True
# 71                  True
# 106                 True
# 270                 True
# 102                 True
#
# [240 rows x 9 columns]

# %%
pre1=model.predict([[5,2071,0,1,0,1,0,0,1]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
pre1
# Out:
# array([11.08846936])

# %% [markdown]
# # Write a program to create a Model using linear regression to predict the wine quality using the csv file provided named “winequality.csv”. Do the required process in the data before making a model.
#
# If you find any null value in “winequality.csv” then replace null value with mean value of respected columns.
# Find co-efficient, intercept and mean squared error.
# also Predict the quality of red wine for the following data:
# fixed acidity: 8
# volatile acidity: 0.4
# citric acid: 0.40
# residual sugar: 15
# chlorides: 0.048
# free sulfur dioxide: 40
# total sulfur dioxide: 150
# density: 0.99
# pH: 3
# sulphates: 0.45
# alcohol: 10.5

# %%
data=pd.read_csv("winequalityN.csv")
data
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
df=pd.DataFrame(data)
df=pd.get_dummies(df)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 6492                 32.0                  44.0  0.99490  3.45       0.58
# 6493                 39.0                  51.0  0.99512  3.52        NaN
# 6494                 29.0                  40.0  0.99574  3.42       0.75
# 6495                 32.0                  44.0  0.99547  3.57       0.71
# 6496                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality  type_red  type_white
# 0         8.8        6     False        True
# 1         9.5        6     False        True
# 2        10.1        6     False        True
# 3         9.9        6     False        True
# 4         9.9        6     False        True
# ...       ...      ...       ...         ...
# 6492     10.5        5      True       False
# 6493     11.2        6      True       False
# 6494     11.0        6      True       False
# 6495     10.2        5      True       False
# 6496     11.0        6      True       False
#
# [6497 rows x 14 columns]

# %%
df.fillna(df.mean(),inplace=True)

# %%
x=df[["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol","type_red"]]
y=df["quality"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
z=model.fit(x_train,y_train)
pre=model.predict(x_test)
pre
# Out:
# array([6.34992927, 6.02349546, 5.76827822, ..., 5.58298533, 5.68576899,
#        5.43735072], shape=(1300,))

# %%
from sklearn.metrics import r2_score,mean_squared_error
acc=r2_score(y_test,pre)
mse=mean_squared_error(y_test,pre)

# %%
acc
# Out:
# 0.3404845408986844

# %%
x_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1916            6.6              0.25         0.36             8.1      0.045
# 947             8.5              0.16         0.35             1.6      0.039
# 877             6.0              0.28         0.34             1.6      0.119
# 2927            7.0              0.31         0.31             9.1      0.036
# 6063            8.5              0.44         0.50             1.9      0.369
# ...             ...               ...          ...             ...        ...
# 3772            6.3              0.24         0.29            13.7      0.035
# 5191            6.9              0.36         0.25             2.4      0.098
# 5226           13.4              0.27         0.62             2.6      0.082
# 5390            8.9              0.40         0.51             2.6      0.052
# 860             8.1              0.27         0.35             1.7      0.030
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1916                 54.0                 180.0  0.99580  3.08       0.42
# 947                  24.0                 147.0  0.99350  2.96       0.36
# 877                  33.0                 104.0  0.99210  3.19       0.38
# 2927                 45.0                 140.0  0.99216  2.98       0.31
# 6063                 15.0                  38.0  0.99634  3.01       1.10
# ...                   ...                   ...      ...   ...        ...
# 3772                 53.0                 134.0  0.99567  3.17       0.38
# 5191                  5.0                  16.0  0.99640  3.41       0.60
# 5226                  6.0                  21.0  1.00020  3.16       0.67
# 5390                 13.0                  27.0  0.99500  3.32       0.90
# 860                  38.0                 103.0  0.99255  3.22       0.63
#
#       alcohol  type_red
# 1916      9.2     False
# 947      10.0     False
# 877      10.2     False
# 2927     12.0     False
# 6063      9.4      True
# ...       ...       ...
# 3772     10.6     False
# 5191     10.1      True
# 5226      9.7      True
# 5390     13.4      True
# 860      10.4     False
#
# [5197 rows x 12 columns]

# %%
pre1=model.predict([[8,0.4,0.4,15,0.048,40,150,0.99,3,0.45,10.5,1]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import  accuracy_score

# %%
data = pd.read_csv("Fish.csv")
df=pd.DataFrame(data)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)
model = KNeighborsClassifier(n_neighbors=3)
model.fit(x_train,y_train)
pre = model.predict(x_test)
acc=accuracy_score(y_test,pre)

# %%
acc
# Out:
# 0.4748717948717949

# %%
for i in range(1,11):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(x_train,y_train)
    pre = model.predict(x_test)
    acc=accuracy_score(y_test,pre)
    print(acc)
# Out:
# 0.5641025641025641
# 0.48923076923076925
# 0.4748717948717949
# 0.4748717948717949
# 0.4625641025641026
# 0.4605128205128205
# 0.4676923076923077
# 0.47794871794871796
# 0.46205128205128204
# 0.46205128205128204

# %%
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
data={
    "movie":["m1","m2","m3","m4"],
    "duration":[150,120,150,110],
    "alevel":[1,2,3,4],
    "type":["action","comedy","comedy","action"]
}

# %%
df1=pd.DataFrame(data)

# %%
df1
# Out:
#   movie  duration  alevel    type
# 0    m1       150       1  action
# 1    m2       120       2  comedy
# 2    m3       150       3  comedy
# 3    m4       110       4  action

# %%
x=df1[["duration","alevel"]]
y=df1["type"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)
model = KNeighborsClassifier(n_neighbors=1)
model.fit(x_train,y_train)
pre = model.predict(x_test)
acc=accuracy_score(y_test,pre)

# %%
acc
# Out:
# 0.0
