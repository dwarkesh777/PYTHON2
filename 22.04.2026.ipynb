# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
data = pd.read_csv("drug200.csv")
df = pd.DataFrame(data)
x=df.drop("Drug",axis=1)
y=df["Drug"]
x=pd.get_dummies(x)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
model = DecisionTreeClassifier(criterion="entropy",max_depth=4,random_state=10)
model.fit(x_train,y_train)
pre=model.predict(x_test)
acc=accuracy_score(y_test,pre)
acc
# Out:
# 1.0

# %%
con=confusion_matrix(y_test,pre)
con

# %%
z=model.classes_

# %%
sns.heatmap(con,annot=True,xticklabels=z,yticklabels=z)
# Out:
# <Axes: >

# %%
x_train
# Out:
#      Age  Na_to_K  Sex_F  Sex_M  BP_HIGH  BP_LOW  BP_NORMAL  Cholesterol_HIGH  Cholesterol_NORMAL
# 169   20   11.262   True  False     True   False      False              True               False
# 97    56   25.395   True  False     True   False      False              True               False
# 31    74    9.567  False   True     True   False      False              True               False
# 12    43   15.376  False   True    False    True      False              True               False
# 35    46    7.285  False   True    False   False       True             False                True
# ..   ...      ...    ...    ...      ...     ...        ...               ...                 ...
# 106   22   11.953  False   True    False   False       True              True               False
# 14    50   12.703   True  False    False   False       True              True               False
# 92    29   29.450   True  False     True   False      False              True               False
# ...

# %%
pre1=model.predict([[20,11.262,1,0,1,0,0,1,0]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
pre1
# Out:
# array(['drugA'], dtype=object)

# %%
data1=pd.read_csv("loan_approval.csv")
df1=pd.DataFrame(data1)

# %%
df1
# Out:
#     Age   Income  CreditScore  LoanAmount  ...  SelfEmployed PropertyArea PreviousLoans LoanApproved
# 0    25  35000.0          620    120000.0  ...            No        Urban             1           No
# 1    42  72000.0          780    200000.0  ...            No    Semiurban             0          Yes
# 2    35  58000.0          690    150000.0  ...           Yes        Rural             2          Yes
# 3    28  26000.0          590    100000.0  ...            No        Urban             1           No
# 4    50  85000.0          810    250000.0  ...            No    Semiurban             0          Yes
# 5    31  46000.0          640    130000.0  ...           Yes        Rural             1           No
# 6    39  67000.0          730    180000.0  ...            No        Urban             0          Yes
# 7    29  31000.0          610    110000.0  ...            No        Rural             2           No
# ...

# %%
df1.isna
# Out:
# <bound method DataFrame.isna of     Age   Income  CreditScore  LoanAmount  ...  SelfEmployed PropertyArea PreviousLoans LoanApproved
# 0    25  35000.0          620    120000.0  ...            No        Urban             1           No
# 1    42  72000.0          780    200000.0  ...            No    Semiurban             0          Yes
# 2    35  58000.0          690    150000.0  ...           Yes        Rural             2          Yes
# 3    28  26000.0          590    100000.0  ...            No        Urban             1           No
# 4    50  85000.0          810    250000.0  ...            No    Semiurban             0          Yes
# 5    31  46000.0          640    130000.0  ...           Yes        Rural             1           No
# 6    39  67000.0          730    180000.0  ...            No        Urban             0          Yes
# 7    29  31000.0          610    110000.0  ...            No        Rural             2           No
# ...

# %%
df1
# Out:
#     Age   Income  CreditScore  LoanAmount  ...  SelfEmployed PropertyArea PreviousLoans LoanApproved
# 0    25  35000.0          620    120000.0  ...            No        Urban             1           No
# 1    42  72000.0          780    200000.0  ...            No    Semiurban             0          Yes
# 2    35  58000.0          690    150000.0  ...           Yes        Rural             2          Yes
# 3    28  26000.0          590    100000.0  ...            No        Urban             1           No
# 4    50  85000.0          810    250000.0  ...            No    Semiurban             0          Yes
# 5    31  46000.0          640    130000.0  ...           Yes        Rural             1           No
# 6    39  67000.0          730    180000.0  ...            No        Urban             0          Yes
# 7    29  31000.0          610    110000.0  ...            No        Rural             2           No
# ...

# %%
df1["Income"]=df1["Income"].fillna(df1["Income"].median)

# %%
df1["Income"].isna
# Out:
# <bound method Series.isna of 0                                               35000.0
# 1                                               72000.0
# 2                                               58000.0
# 3                                               26000.0
# 4                                               85000.0
# 5                                               46000.0
# 6                                               67000.0
# 7                                               31000.0
# 8                                               79000.0
# 9                                               52000.0
# 10    <bound method Series.median of 0     35000.0\n...
# 11                                              72000.0
# 12                                              28000.0
# Name: Income, dtype: object>

# %%
df1["CreditScore"]=df1["CreditScore"].fillna(df1["CreditScore"].median)

# %%
sns.barplot(df1,x="Income",y="PropertyArea")
# Out:
# <Axes: xlabel='Income', ylabel='PropertyArea'>

# %%
df1.drop_duplicates()
# Out:
#     Age                                             Income  CreditScore  ...  PropertyArea  PreviousLoans LoanApproved
# 0    25                                            35000.0          620  ...         Urban              1           No
# 1    42                                            72000.0          780  ...     Semiurban              0          Yes
# 2    35                                            58000.0          690  ...         Rural              2          Yes
# 3    28                                            26000.0          590  ...         Urban              1           No
# 4    50                                            85000.0          810  ...     Semiurban              0          Yes
# 5    31                                            46000.0          640  ...         Rural              1           No
# 6    39                                            67000.0          730  ...         Urban              0          Yes
# ...

# %%
x1=df1.drop("LoanApproved",axis=1)

# %%
y1=df1["LoanApproved"]

# %%
x1=pd.get_dummies(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=42)
model=DecisionTreeClassifier(criterion="entropy")
model.fit(x_train,y_train)
pre=model.predict(x_test)
acc=accuracy_score(y_test,pre)
acc
# Out:
# 0.6666666666666666

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=42)
model1=KNeighborsClassifier(n_neighbors=3)
model1.fit(x_train,y_train)
pre1=model1.predict(x_test)
acc1=accuracy_score(y_test1,pre1)
acc1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 3
#       1 x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=42)
#       2 model1=KNeighborsClassifier(n_neighbors=3)
# ----> 3 model1.fit(x_train,y_train)
#       4 pre1=model1.predict(x_test)
#       5 acc1=accuracy_score(y_test1,pre1)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# ...
