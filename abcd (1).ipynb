# %% [markdown]
# # partA

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,accuracy_score,mean_squared_error,precision_score,recall_score,confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
data = pd.read_csv("house_price_analysis.csv")
df= pd.DataFrame(data)

# %%
df.head(5)
# Out:
#    Area  Bedrooms  Bathrooms  Age  Parking  LocationScore    Price
# 0   900         2          1   10        1              6  3200000
# 1  1100         2          2    8        1              7  4200000
# 2  1400         3          2    6        1              8  5500000
# 3  1600         3          3    5        2              9  6800000
# 4  1800         4          3    4        2              9  7600000

# %%
df.shape
# Out:
# (15, 7)

# %%
df.columns
# Out:
# Index(['Area', 'Bedrooms', 'Bathrooms', 'Age', 'Parking', 'LocationScore',
#        'Price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Area             int64
# Bedrooms         int64
# Bathrooms        int64
# Age              int64
# Parking          int64
# LocationScore    int64
# Price            int64
# dtype: object

# %%
df.isna
# Out:
# <bound method DataFrame.isna of     Area  Bedrooms  Bathrooms  Age  Parking  LocationScore    Price
# 0    900         2          1   10        1              6  3200000
# 1   1100         2          2    8        1              7  4200000
# 2   1400         3          2    6        1              8  5500000
# 3   1600         3          3    5        2              9  6800000
# 4   1800         4          3    4        2              9  7600000
# 5   1000         2          1   12        1              6  3500000
# 6   1250         3          2    7        1              7  4900000
# 7   1500         3          2    5        2              8  6100000
# 8   1700         4          3    3        2              9  7300000
# 9   2000         4          4    2        3             10  9200000
# 10   950         2          1   11        1              6  3300000
# 11  1350         3          2    6        1              8  5200000
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Area  Bedrooms  Bathrooms  Age  Parking  LocationScore    Price
# 0    900         2          1   10        1              6  3200000
# 1   1100         2          2    8        1              7  4200000
# 2   1400         3          2    6        1              8  5500000
# 3   1600         3          3    5        2              9  6800000
# 4   1800         4          3    4        2              9  7600000
# 5   1000         2          1   12        1              6  3500000
# 6   1250         3          2    7        1              7  4900000
# 7   1500         3          2    5        2              8  6100000
# 8   1700         4          3    3        2              9  7300000
# 9   2000         4          4    2        3             10  9200000
# 10   950         2          1   11        1              6  3300000
# 11  1350         3          2    6        1              8  5200000
# ...

# %% [markdown]
# # partc

# %%
df
# Out:
#     Area  Bedrooms  Bathrooms  Age  Parking  LocationScore    Price
# 0    900         2          1   10        1              6  3200000
# 1   1100         2          2    8        1              7  4200000
# 2   1400         3          2    6        1              8  5500000
# 3   1600         3          3    5        2              9  6800000
# 4   1800         4          3    4        2              9  7600000
# 5   1000         2          1   12        1              6  3500000
# 6   1250         3          2    7        1              7  4900000
# 7   1500         3          2    5        2              8  6100000
# 8   1700         4          3    3        2              9  7300000
# 9   2000         4          4    2        3             10  9200000
# 10   950         2          1   11        1              6  3300000
# 11  1350         3          2    6        1              8  5200000
# 12  1550         3          3    4        2              8  6400000
# ...

# %%
x=df[["Area"]]
y=df["Price"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
pre=model.predict(x_test)
acc1= r2_score(y_test,pre)

# %%
acc
# Out:
# 0.9945285670340245

# %%
x1=df.drop("Price",axis=1)

# %%
y1=df["Price"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=42)
model1=LinearRegression()
model1.fit(x_train,y_train)
pre1=model1.predict(x_test)
acc2= r2_score(y_test,pre1)

# %%
acc1
# Out:
# 0.9906476551249069

# %%
poly=PolynomialFeatures(degree=3)
x_poly_train=poly.fit_transform(x_train)
x_poly_test=poly.transform(x_test)

model=LinearRegression()
model.fit(x_poly_train,y_train)
pre=model.predict(x_poly_test)
pre

acc3=r2_score(y_test,pre)
print(acc)
mse=mean_squared_error(y_test,pre)
print(mse)
# Out:
# 0.9945285670340245
# 34044471788.291973

# %% [markdown]
# # partD

# %%
import numpy as np

# %%
df["n_price"]=np.where((df["Price"]>df["Price"].median()),1,0)

# %%
df
# Out:
#     Area  Bedrooms  Bathrooms  Age  Parking  LocationScore    Price  n_price
# 0    900         2          1   10        1              6  3200000        0
# 1   1100         2          2    8        1              7  4200000        0
# 2   1400         3          2    6        1              8  5500000        0
# 3   1600         3          3    5        2              9  6800000        1
# 4   1800         4          3    4        2              9  7600000        1
# 5   1000         2          1   12        1              6  3500000        0
# 6   1250         3          2    7        1              7  4900000        0
# 7   1500         3          2    5        2              8  6100000        0
# 8   1700         4          3    3        2              9  7300000        1
# 9   2000         4          4    2        3             10  9200000        1
# 10   950         2          1   11        1              6  3300000        0
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
x=df.drop("n_price",axis=1)

# %%
y=df["n_price"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=KNeighborsClassifier(n_neighbors=3)
model.fit(x_train,y_train)
pre=model.predict(x_test)
acc= r2_score(y_test,pre)

# %%
acc
# Out:
# 1.0

# %%
con=confusion_matrix(y_test,pre)

# %%
con
# Out:
# array([[2, 0],
#        [0, 1]])

# %%
recall=recall_score(y_test,pre)

# %%
recall
# Out:
# 1.0

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
x=df.drop("n_price",axis=1)

# %%
y=df["n_price"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model= DecisionTreeClassifier(criterion="entropy")

# %%
model.fit(x_train,y_train)
pre=model.predict(x_test)
acc= r2_score(y_test,pre)

# %%
acc
# Out:
# 1.0

# %%
d={
    "Model":["Simple LR","Multiple LR","Polynomial"],
    "R2":[acc1,acc2,acc3]
}

# %%
d1=pd.DataFrame(d)

# %%
d1
# Out:
#          Model        R2
# 0    Simple LR  0.990648
# 1  Multiple LR  0.998118
# 2   Polynomial  0.994529

# %%
data = pd.read_csv("Churn.csv")
df1=pd.DataFrame(data)

# %%
df1
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
x=df1.drop(columns=["customerID","Churn"],axis=1)

# %%
y=df1["Churn"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=KNeighborsClassifier(n_neighbors=3)
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4300\2090769255.py in ?()
#       1 model=KNeighborsClassifier(n_neighbors=3)
# ----> 2 model.fit(x_train,y_train)
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py in ?(self, X, y)
#     235         -------
#     236         self : KNeighborsClassifier
#     237             The fitted k-nearest neighbors classifier.
#     238         """
# --> 239         return self._fit(X, y)
#
# ...
