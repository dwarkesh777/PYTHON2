# %%
import pandas as pd

# %%
f=pd.read_csv("demo.csv")
df=pd.DataFrame(f)
x=df[["A"]]
y=df["B"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
z=model.fit(x_train,y_train)
pre=model.predict(x_test)
pre
# Out:
# array([35., 10., 30.])

# %%
from sklearn.metrics import r2_score,mean_squared_error
acc=r2_score(y_test,pre)
mse=mean_squared_error(y_test,pre)
int(mse)
acc
# Out:
# 1.0

# %%
model.intercept_
# Out:
# np.float64(7.105427357601002e-15)

# %%
model.coef_
# Out:
# array([5.])

# %%
pre1=model.predict([[21035]])
pre1
# Out:
# C:\Users\Manin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([105175.])

# %%
f1=pd.read_csv("heights_weights.csv")
df1=pd.DataFrame(f1)
df1
# Out:
#          Height      Weight  Male
# 0     73.847017  241.893563     1
# 1     68.781904  162.310473     1
# 2     74.110105  212.740856     1
# 3     71.730978  220.042470     1
# 4     69.881796  206.349801     1
# ...         ...         ...   ...
# 9995  66.172652  136.777454     0
# 9996  67.067155  170.867906     0
# 9997  63.867992  128.475319     0
# 9998  69.034243  163.852461     0
# 9999  61.944246  113.649103     0
#
# [10000 rows x 3 columns]

# %%
x=df1[["Height","Male"]]
y=df1["Weight"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
a=model.fit(x_train,y_train)
pre=model.predict(x_test)
pre
# Out:
# array([165.58497097, 185.78096721, 171.25903401, ..., 126.76971077,
#        175.2620878 , 105.52795239], shape=(2000,))

# %%
acc=r2_score(y_test,pre)
acc
# Out:
# 0.9033321846361925

# %%
mse=mean_squared_error(y_test,pre)
mse
# Out:
# 101.24427647013303

# %%
model.intercept_
# Out:
# np.float64(-244.6935679363921)

# %%
model.coef_
# Out:
# array([ 5.97314123, 19.34720343])

# %%
for i in range(1,7):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    a=model.fit(x_train,y_train)
    pre=model.predict(x_test)
    pre
    acc=r2_score(y_test,pre)
    print("Accuracy:" , acc)
    mse=mean_squared_error(y_test,pre)
    print("Mean sqaured error:" ,mse)
# Out:
# Accuracy: 0.9066484076989247
# Mean sqaured error: 100.08196706849057
# Accuracy: 0.9037416940055818
# Mean sqaured error: 101.34697122797286
# Accuracy: 0.9029205050902992
# Mean sqaured error: 100.88455655163914
# Accuracy: 0.9019621077541354
# Mean sqaured error: 100.96575552067709
# Accuracy: 0.9001202080258648
# Mean sqaured error: 98.00438314457736
# Accuracy: 0.9044751565929283
# Mean sqaured error: 99.89255988290948

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
y=sns.scatterplot(x=y_test,y=pre)
plt.show()

# %%
#random state=3 0.2=> test size

# %%
#ignore species column , other rest are indepedent and weight are depenedent

# %%
f=pd.read_csv("Fish.csv")
df=pd.DataFrame(f)
x=df[["Length3"]]
y=df["Weight"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
z=model.fit(x_train,y_train)
pre=model.predict(x_test)
pre
# Out:
# array([ 291.52388243,  437.93805906,  148.47918773,  808.90977341,
#         360.76410599,  357.30788677,  675.45310943,  499.11848653,
#         135.1638162 ,  230.91738006,  613.21183254,  933.03767527,
#         445.16117667,   93.46601507,  369.78582982,  467.90197324,
#         185.11949927,  136.6529797 , -171.11250719,  860.17688244,
#         163.2989708 ,  216.62733607,  211.26057458,  219.88530416,
#        -167.41324718,  136.48158828,  468.88116564,  981.72822954,
#        -233.65228842, -263.71264808,  454.57145822,  775.59438965])

# %%
from sklearn.metrics import r2_score,mean_squared_error
acc=r2_score(y_test,pre)
mse=mean_squared_error(y_test,pre)
print(int(mse))
acc
# Out:
# 12680
# 0.8618902278320013

# %%
f=pd.read_csv("Fish.csv")
df=pd.DataFrame(f)
x=df[["Length1","Length2","Length3","Height","Width"]]
y=df["Weight"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
z=model.fit(x_train,y_train)
pre=model.predict(x_test)
pre
# Out:
# array([ 291.52388243,  437.93805906,  148.47918773,  808.90977341,
#         360.76410599,  357.30788677,  675.45310943,  499.11848653,
#         135.1638162 ,  230.91738006,  613.21183254,  933.03767527,
#         445.16117667,   93.46601507,  369.78582982,  467.90197324,
#         185.11949927,  136.6529797 , -171.11250719,  860.17688244,
#         163.2989708 ,  216.62733607,  211.26057458,  219.88530416,
#        -167.41324718,  136.48158828,  468.88116564,  981.72822954,
#        -233.65228842, -263.71264808,  454.57145822,  775.59438965])

# %%
from sklearn.metrics import r2_score,mean_squared_error
acc=r2_score(y_test,pre)
mse=mean_squared_error(y_test,pre)
print(mse)
print(acc)
# Out:
# 12680.353910507434
# 0.8618902278320013

# %%
model.intercept_
# Out:
# np.float64(-516.7128473298877)

# %%
model.coef_
# Out:
# array([ 67.55940439, -18.22763355, -22.57284496,  25.19276393,
#         31.85419489])

# %%
# f=pd.read_csv("Fish.csv")
# df=pd.DataFrame(f)
# x=df[["Species","Length1","Length2","Length3","Height","Width"]]
# y=df["Weight"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
# f = pd.read_csv("Fish.csv")
# df = pd.DataFrame(f)

# x = pd.get_dummies(df[["Species","Length1","Length2","Length3","Height","Width"]])

# y = df["Weight"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
z=model.fit(x_train,y_train)
pre=model.predict(x_test)
pre
# Out:
# array([ 259.76363602,  427.00019626,   72.2994054 ,  876.19631114,
#         398.65572113,  400.66946334,  749.11704672,  481.33858138,
#         118.51968452,  237.35935955,  560.41582902,  993.21088083,
#         449.1965386 ,   59.91197857,  272.50554082,  337.73701479,
#         161.50934853,   96.74212425,    7.69727599,  805.52304052,
#         159.91840132,  138.28189099,  200.08483512,  210.81661033,
#          -3.12469772,  123.32081027,  493.58653325,  968.99115725,
#         -87.65621402, -448.44512514,  429.65967198,  827.99391445])

# %%
from sklearn.metrics import r2_score,mean_squared_error
acc=r2_score(y_test,pre)
mse=mean_squared_error(y_test,pre)
print(mse)
print(acc)
# Out:
# 11004.070885877587
# 0.8801476888030925

# %%
model.intercept_
# Out:
# np.float64(-880.7605832095352)

# %%
model.coef_
# Out:
# array([ -80.66928147,   59.48093084,   55.34446847,    4.7103662 ,
#         -11.10057109, -160.12817296,   91.91361637,   56.34523826,
#        -352.10812768,   11.26748423,  366.13387877,  -13.423917  ])

# %%
x=df[["Length1","Length2","Length3","Height","Width"]]
y=df["Weight"]

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.preprocessing import PolynomialFeatures


poly=PolynomialFeatures(degree=3)
x_poly_train=poly.fit_transform(x_train)
x_poly_test=poly.transform(x_test)

model=LinearRegression()
model.fit(x_poly_train,y_train)
pre=model.predict(x_poly_test)
pre

acc=r2_score(y_test,pre)
print(acc)
mse=mean_squared_error(y_test,pre)
print(mse)
# Out:
# 0.9609431981536263
# 5555.411640720724

# %%
for d in range(1, 21):   
    poly = PolynomialFeatures(degree=d)
    
    x_train_poly = poly.fit_transform(x_train)
    x_test_poly = poly.transform(x_test)
    
    model = LinearRegression()
    model.fit(x_train_poly, y_train)
    
    pred = model.predict(x_test_poly)
    
    print("Degree:", d, "R2 Score:", r2_score(y_test, pred))
# Out:
# Degree: 1 R2 Score: 0.8821430593048695
# Degree: 2 R2 Score: 0.967267505578677
# Degree: 3 R2 Score: 0.9609431981536263
# Degree: 4 R2 Score: -422.86498960818193
# Degree: 5 R2 Score: -428.91735619536126
# Degree: 6 R2 Score: -1306.7900166815982
# Degree: 7 R2 Score: -3862.1649275848317
# Degree: 8 R2 Score: -7218.979565077533
# Degree: 9 R2 Score: -158961.26482875008
# Degree: 10 R2 Score: -202694.37855953287
# Degree: 11 R2 Score: -224722.91228801457
# Degree: 12 R2 Score: -286542.6656745368
# Degree: 13 R2 Score: -1522401.0060730246
# Degree: 14 R2 Score: -408107.9189271423
# Degree: 15 R2 Score: -5648136.742996424
# Degree: 16 R2 Score: -49577419.375175186
# Degree: 17 R2 Score: -129881513.52135083
# Degree: 18 R2 Score: -14980437.161714101
# Degree: 19 R2 Score: -1132838.3334957757
# Degree: 20 R2 Score: -6594575.567189461

# %%
import matplotlib.pyplot as plt

degrees = []
scores = []

for d in range(1, 21):
    poly = PolynomialFeatures(degree=d)
    
    x_train_poly = poly.fit_transform(x_train)
    x_test_poly = poly.transform(x_test)
    
    model = LinearRegression()
    model.fit(x_train_poly, y_train)
    
    pred = model.predict(x_test_poly)
    
    score = r2_score(y_test, pred)
    
    degrees.append(d)
    scores.append(score)

plt.bar(degrees, scores)
plt.xlabel("Degree")
plt.ylabel("R2 Score")
plt.show()

# %% [markdown]
# For x = np.array([5, 15, 25, 35, 45, 55]) and y = np.array([5, 20, 14, 32, 22, 38]),
# apply simple linear regression using scikit learn library and calculate calculate R squared,
# coeficient and intercept. Predict the y values for x = np.arange(5). (Don't split data for training/testing)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

x = np.array([5, 15, 25, 35, 45, 55]).reshape(-1, 1)
y = np.array([5, 20, 14, 32, 22, 38])

model = LinearRegression()
model.fit(x, y)

y_pred = model.predict(x)

print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
print("R2 Score:", r2_score(y, y_pred))

x_new = np.arange(5).reshape(-1, 1)
y_new_pred = model.predict(x_new)

print(y_new_pred)
# Out:
# Coefficient: [0.54]
# Intercept: 5.633333333333329
# R2 Score: 0.7158756137479542
# [5.63333333 6.17333333 6.71333333 7.25333333 7.79333333]

# %% [markdown]
# Given a dataset with 'SAT' scores as independent variables and 'GPA' as the dependent variable,
# calculate R squared, coeficient and
# intercept using linear regression and scikitlearn library. (Don't split data for training/testing)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

df = pd.read_csv("SATGPA.csv")

X = df[["SAT"]]    
y = df["GPA"]


model = LinearRegression()
model.fit(X, y)


y_pred = model.predict(X)

r2 = r2_score(y, y_pred)
coef = model.coef_[0]
intercept = model.intercept_


print("R2 Score:", r2)
print("Coefficient:", coef)
print("Intercept:", intercept)
# Out:
# R2 Score: 0.40600391479679765
# Coefficient: 0.0016556880500928138
# Intercept: 0.27504029966028076

# %% [markdown]
# Given a real estate price size year dataset, implement multiple linear regression
# using scikitlearn library. Using the model, make a prediction about an apartment price with size 750 sq.ft. for
# 2009.Also Calculate R squared, coeficient and intercept. (Don't split data for training/testing)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv("real_estate.csv")

X = df[["size", "year"]]   
y = df["price"]            

model = LinearRegression()
model.fit(X, y)

print("R² Score:", model.score(X, y))   
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)

pred = model.predict(pd.DataFrame([[750, 2009]], columns=["size", "year"]))
print("Predicted Price:", pred[0])
# Out:
# R² Score: 0.7764803683276793
# Coefficients: [ 227.70085401 2916.78532684]
# Intercept: -5772267.017463277
# Predicted Price: 258330.34465994593
